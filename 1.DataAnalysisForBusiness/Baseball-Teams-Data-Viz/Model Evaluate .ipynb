# %% [markdown]
# #### Model 4

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# fill negative/blank value

df = pd.read_csv('baseball_teams.csv')
df = df.fillna(0)

#TP4 Defensive Model
df4 = df[(df['Year '] >= 1960) & (df['Year '] <= 2020)]
X4 = df4[['Earned_Runs', 'Walks_Allowed', 'Strikeouts_Allowed', 'Errors']]
y4 = df4['Games_Won']
model4 = LinearRegression()
model4.fit(X4, y4)

#Make predictions using the model
y4_pred = model4.predict(X4)

#Plot the actual vs predicted values
plt.figure(figsize=(10, 8))
plt.scatter(y4, y4_pred)
plt.plot(y4, np.poly1d(np.polyfit(y4, y4_pred, 1))(y4), color='red')
plt.plot([min(y4), max(y4)], [min(y4), max(y4)], color='green', linestyle='--')
plt.xlabel("Actual Games Won")
plt.ylabel("Predicted Games Won")
plt.title("TP4 Defensive Model")
plt.show()

# %%
#using model 4 for yankees,2012 #actual_games_won = 95
import numpy as np

# Input values
input_stats = np.array([617, 431, 1318, 75]).reshape(1,-1)


# Predict games won
predicted_games_won = model4.predict(input_stats)

print("Predicted games won: ", predicte
      
      d_games_won)
# Out:
# Predicted games won:  [91.01696297]
# /Users/ajaydhamanda/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#using model 4 for yankees,2015 #actual_games_won = 89
import numpy as np

# Input values
input_stats = np.array([652, 474, 1370, 93]).reshape(1,-1)

# Predict games won
predicted_games_won = model4.predict(input_stats)

print("Predicted games won: ", predicted_games_won)
# Out:
# Predicted games won:  [90.77344009]
# /Users/ajaydhamanda/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#using model 4 for toronto,2012 #actual_games_won = 73
import numpy as np

# Input values
input_stats = np.array([745, 574, 1142, 101]).reshape(1,-1)

# Predict games won
predicted_games_won = model4.predict(input_stats)

print("Predicted games won: ", predicted_games_won)
# Out:
# Predicted games won:  [80.00176665]
# /Users/ajaydhamanda/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#using model 4 for toronto,2015 #actual_games_won = 93
import numpy as np

# Input values
input_stats = np.array([609, 397, 1117, 88]).reshape(1,-1)

# Predict games won
predicted_games_won = model4.predict(input_stats)

print("Predicted games won: ", predicted_games_won)
# Out:
# Predicted games won:  [85.98151026]
# /Users/ajaydhamanda/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
#using model 4 for yankees,2012 #actual_games_won = 95


import numpy as np
from sklearn.metrics import mean_squared_error

#using model 4 for yankees,2012 #actual_games_won = 95
mse1 = mean_squared_error([95], [91])
rmse1 = np.sqrt(mse1)

print("RMSE: ", rmse1)
# Out:
# RMSE:  4.0

# %%
#using model 4 for yankees,2015 #actual_games_won = 89
mse2 = mean_squared_error([89], [90.9])
rmse2 = np.sqrt(mse2)

print("RMSE: ", rmse2)
# Out:
# RMSE:  1.9000000000000057

# %%
#using model 4 for toronto,2012 #actual_games_won = 73
mse3 = mean_squared_error([73], [80])
rmse3 = np.sqrt(mse3)

print("RMSE: ", rmse3)
# Out:
# RMSE:  7.0

# %%
#using model 4 for toronto,2015 #actual_games_won = 93
mse4 = mean_squared_error([93], [86])
rmse4 = np.sqrt(mse4)

print("RMSE: ", rmse4)
# Out:
# RMSE:  7.0
